# %% [markdown]
# # Семинар. Предообработка текста
#
# # Часть 1
# ## Токенизация

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\kuzmi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %% [markdown]
# можем выполнить токенизацию по словам

# %%
data = "All work and no play makes jack a dull boy, all work and no play"
tokens = word_tokenize(data.lower())
print(tokens)
# Out:
# ['all', 'work', 'and', 'no', 'play', 'makes', 'jack', 'a', 'dull', 'boy', ',', 'all', 'work', 'and', 'no', 'play']

# %% [markdown]
# а также по предложениями

# %%
print(sent_tokenize('I was going home when she rung. It was a surprise.'))
# Out:
# ['I was going home when she rung.', 'It was a surprise.']

# %% [markdown]
# чтобы работать с текстом на русском языке, можно установить razdel или natasha

# %%
# !pip install -q razdel

# %%
from razdel import tokenize, sentenize
text = 'Кружка-термос на 0.5л (50/64 см³, 516;...)'
list(tokenize(text))
# Out:
# [Substring(0, 13, 'Кружка-термос'),
#  Substring(14, 16, 'на'),
#  Substring(17, 20, '0.5'),
#  Substring(20, 21, 'л'),
#  Substring(22, 23, '('),
#  Substring(23, 28, '50/64'),
#  Substring(29, 32, 'см³'),
#  Substring(32, 33, ','),
#  Substring(34, 37, '516'),
#  Substring(37, 38, ';'),
#  Substring(38, 41, '...'),
#  Substring(41, 42, ')')]

# %% [markdown]
# можем заметить что он по шаблонам определил, что например 0.5 является числом, а 50/64 - дробью

# %% [markdown]
# ## Регулярные выражения

# %%
import re
word = 'supercalifragilisticexpialidocious'
re.findall('[abc]|up|super', word)
# Out:
# ['super', 'c', 'a', 'a', 'c', 'a', 'c']

# %%
re.findall('\d{1,3}', 'These are some numbers: 49 and 432312')
# Out:
# ['49', '432', '312']

# %%
re.sub('[,\.?!]','','How, to? split. text!')
# Out:
# 'How to split text'

# %%
re.sub('[^A-z]',' ','I 123 can 45 play 67 football').split()
# Out:
# ['I', 'can', 'play', 'football']

# %% [markdown]
# регулярные выражения позволяют обработать текст по определенным шаблонам
